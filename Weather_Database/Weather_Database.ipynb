# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Use the print() function to display the latitude and longitude combinations.
#for coordinate in coordinates:
    #print(coordinate[0], coordinate[1])

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
cities
# Out:
# ['kuche',
#  'punta arenas',
#  'ribeira grande',
#  'ushuaia',
#  'arlit',
#  'boguchany',
#  'arrifes',
#  'myanaung',
#  'champasak',
#  'ponta do sol',
#  'bredasdorp',
#  'butaritari',
#  'jamestown',
#  'bilma',
#  'east london',
#  'tasiilaq',
#  'zonguldak',
#  'kisangani',
#  'puerto ayora',
#  'cape town',
#  'maunabo',
#  'hermanus',
#  'caravelas',
#  'rikitea',
#  'onega',
#  'saint george',
#  'betong',
#  'bayamo',
#  'olafsvik',
#  'prainha',
#  'vila velha',
#  'bluff',
#  'peniche',
#  'albany',
#  'carupano',
#  'codrington',
#  'vestmannaeyjar',
#  'xushan',
#  'pevek',
#  'nishihara',
#  'norman wells',
#  'chuy',
#  'illoqqortoormiut',
#  'pasighat',
#  'hobart',
#  'bacolod',
#  'jinchang',
#  'cochrane',
#  'kalmunai',
#  'te anau',
#  'kavaratti',
#  'maarianhamina',
#  'barrow',
#  'laguna',
#  'kapaa',
#  'nalbari',
#  'new norfolk',
#  'grand river south east',
#  'burnie',
#  'ongandjera',
#  'barentsburg',
#  'dubai',
#  'banff',
#  'harper',
#  'arraial do cabo',
#  'lebu',
#  'faya',
#  'fortuna',
#  'kanigiri',
#  'lagoa',
#  'orlik',
#  'yellowknife',
#  'severo-kurilsk',
#  'sao miguel',
#  'san cristobal',
#  'kaitangata',
#  'srednekolymsk',
#  'hambantota',
#  'araouane',
#  'terney',
#  'jumla',
#  'goderich',
#  'beringovskiy',
#  'bismarck',
#  'linxi',
#  'republic',
#  'pemangkat',
#  'fukue',
#  'svetlogorsk',
#  'neiafu',
#  'saskylakh',
#  'sechura',
#  'nanlong',
#  'dikson',
#  'calbuco',
#  'nagorsk',
#  'coruripe',
#  'tiksi',
#  'longyearbyen',
#  'qurbah',
#  'nikolskoye',
#  'salinas',
#  'halalo',
#  'la ronge',
#  'flinders',
#  'senanga',
#  'taolanaro',
#  'cabo san lucas',
#  'ravar',
#  'rajula',
#  'megion',
#  'port keats',
#  'hithadhoo',
#  'chokurdakh',
#  'olot',
#  'zeljezno polje',
#  'mataura',
#  'clyde river',
#  'mansa',
#  'khani',
#  'yamada',
#  'concepcion del oro',
#  'linhares',
#  'luderitz',
#  'byron bay',
#  'aswan',
#  'lata',
#  'bandarbeyla',
#  'esperance',
#  'port moresby',
#  'palmer',
#  'cherskiy',
#  'mouzakion',
#  'upernavik',
#  'faanui',
#  'smithers',
#  'tomiya',
#  'busselton',
#  'port alfred',
#  'kahului',
#  'hilo',
#  'kodiak',
#  'lompoc',
#  'bethel',
#  'richard toll',
#  'thompson',
#  'koulamoutou',
#  'nago',
#  'zhigansk',
#  'matale',
#  'ambon',
#  'hit',
#  'kirakira',
#  'borogontsy',
#  'ileza',
#  'korla',
#  'bonavista',
#  'port elizabeth',
#  'yershov',
#  'knysna',
#  'kilindoni',
#  'rocha',
#  'ausa',
#  'coihaique',
#  'hamilton',
#  'marzuq',
#  'xique-xique',
#  'qaanaaq',
#  'padang',
#  'cidreira',
#  'airai',
#  'port lincoln',
#  'shenjiamen',
#  'vardo',
#  'meulaboh',
#  'talavera de la reina',
#  'mahebourg',
#  'mirnyy',
#  'rungata',
#  'chapais',
#  'namatanai',
#  'katsuura',
#  'balboa',
#  'tsihombe',
#  'mar del plata',
#  'avarua',
#  'evanston',
#  'tumannyy',
#  'nantucket',
#  'viedma',
#  'hami',
#  'russkaya polyana',
#  'nanortalik',
#  'cayenne',
#  'ito',
#  'maldonado',
#  'hovd',
#  'villa union',
#  'vaitupu',
#  'lumut',
#  'mandal',
#  'samusu',
#  'victoria',
#  'mishkino',
#  'mullaitivu',
#  'san patricio',
#  'vaini',
#  'saint-francois',
#  'narsaq',
#  'batagay-alyta',
#  'roald',
#  'georgetown',
#  'leningradskiy',
#  'meiringen',
#  'shakawe',
#  'fougamou',
#  'vilyuysk',
#  'brikama',
#  'sao felix do xingu',
#  'saldanha',
#  'maltahohe',
#  'saint anthony',
#  'maamba',
#  'nemuro',
#  'castellarano',
#  'luanda',
#  'sao filipe',
#  'arkhipo-osipovka',
#  'phan thiet',
#  'castro',
#  'vanimo',
#  'college',
#  'karpathos',
#  'bar harbor',
#  'deputatskiy',
#  'kanlagay',
#  'saint-philippe',
#  'gisborne',
#  'pemberton',
#  'sentyabrskiy',
#  'richards bay',
#  'tura',
#  'lorengau',
#  'mackay',
#  'inirida',
#  'caraguatatuba',
#  'san rafael del sur',
#  'southbridge',
#  'svetlaya',
#  'ilulissat',
#  'aklavik',
#  'atuona',
#  'hokitika',
#  'leh',
#  'ridgeland',
#  'yonago',
#  'sondershausen',
#  'amderma',
#  'saint-pierre',
#  'shimoda',
#  'bara',
#  'ormara',
#  'buala',
#  'ahuimanu',
#  'atherton',
#  'santiago de cao',
#  'serebryansk',
#  'vadso',
#  'porto novo',
#  'whitehorse',
#  'klaksvik',
#  'provideniya',
#  'tuatapere',
#  'condega',
#  'pionerskiy',
#  'basna',
#  'oak harbor',
#  'tabiauea',
#  'takoradi',
#  'barranca',
#  'natal',
#  'attawapiskat',
#  'high rock',
#  'guia de isora',
#  'cururupu',
#  'mount isa',
#  'haines junction',
#  'ahipara',
#  'grand centre',
#  'vao',
#  'naze',
#  'matay',
#  'anadyr',
#  'ranong',
#  'harboore',
#  'osmanabad',
#  'ancud',
#  'dumai',
#  'torbay',
#  'kenda',
#  'bengkalis',
#  'mgandu',
#  'manokwari',
#  'thilogne',
#  'ippy',
#  'isangel',
#  'hofn',
#  'porosozero',
#  'duluth',
#  'chumikan',
#  'bengkulu',
#  'lolua',
#  'nome',
#  'hamamatsu',
#  'imbituba',
#  'tuktoyaktuk',
#  'san julian',
#  'dingle',
#  'japura',
#  'safwah',
#  'sao joao da barra',
#  'quatre cocos',
#  'valparaiso',
#  'mys shmidta',
#  'hakkari',
#  'kodinar',
#  'zeya',
#  'carnarvon',
#  'tagusao',
#  'alofi',
#  'honningsvag',
#  'lloydminster',
#  'odweyne',
#  'guye',
#  'karaul',
#  'gouyave',
#  'bontang',
#  'belushya guba',
#  'scarborough',
#  'carutapera',
#  'sitka',
#  'santa ines',
#  'solnechnyy',
#  'samalaeulu',
#  'emba',
#  'dzhusaly',
#  'mildura',
#  'lilongwe',
#  'wenatchee',
#  'aykhal',
#  'jiazi',
#  'le mars',
#  'zmievka',
#  'gushikawa',
#  'cozumel',
#  'gravdal',
#  'exaplatanos',
#  'xining',
#  'manyoni',
#  'ust-kuyga',
#  'sola',
#  'antalaha',
#  'sault sainte marie',
#  'ihosy',
#  'kosmynino',
#  'ossora',
#  'melo',
#  'broken hill',
#  'cap-chat',
#  'san vicente',
#  'tabuk',
#  'souillac',
#  'taoudenni',
#  'santa cruz de tenerife',
#  'hualmay',
#  'hobyo',
#  'north bend',
#  'geraldton',
#  'kinna',
#  'golden',
#  'jiangyou',
#  'komsomolskiy',
#  'danville',
#  'freeport',
#  'gamba',
#  'havelock',
#  'walvis bay',
#  'asosa',
#  'rapid valley',
#  'kruisfontein',
#  'auburn',
#  'pimentel',
#  'roma',
#  'pangody',
#  'pacific grove',
#  'zarubino',
#  'westport',
#  'picota',
#  'rocky mountain house',
#  'khatanga',
#  'sedelnikovo',
#  'columbus',
#  'camopi',
#  'kaeo',
#  'lithakia',
#  'koungou',
#  'elko',
#  'gormi',
#  'avera',
#  'verkhnevilyuysk',
#  'vagay',
#  'kambove',
#  'fairbanks',
#  'mariana',
#  'haibowan',
#  'lewisporte',
#  'xichang',
#  'dzhebariki-khaya',
#  'makakilo city',
#  'juegang',
#  'stephenville',
#  'arman',
#  'tezu',
#  'san pedro',
#  'abong mbang',
#  'mont-de-marsan',
#  'pangnirtung',
#  'port hardy',
#  'aripuana',
#  'usta muhammad',
#  'pilar',
#  'bassano',
#  'nakapiripirit',
#  'labuhan',
#  'vila franca do campo',
#  'birjand',
#  'williamsport',
#  'muros',
#  'toliary',
#  'shamgarh',
#  'yelnya',
#  'atar',
#  'conceicao do araguaia',
#  'comodoro rivadavia',
#  'gelemso',
#  'katobu',
#  'ledyard',
#  'galveston',
#  'zalari',
#  'mikhaylovka',
#  'janauba',
#  'pamyat parizhskoy kommuny',
#  'uvalde',
#  'kavieng',
#  'rongcheng',
#  'saryshagan',
#  'berlevag',
#  'maine-soroa',
#  'nyurba',
#  'bahia blanca',
#  'lavrentiya',
#  'maragogi',
#  'tiznit',
#  'mont-dore',
#  'kenai',
#  'gerash',
#  'beeville',
#  'hasaki',
#  'kopyevo',
#  'iqaluit',
#  'chumphon',
#  'jingdezhen',
#  'verkh-usugli',
#  'pelym',
#  'winslow',
#  'vostok',
#  'paamiut',
#  'vestmanna',
#  'gari',
#  'umm lajj',
#  'boshnyakovo',
#  'yerbogachen',
#  'dmitriyev-lgovskiy',
#  'jacala',
#  'boende',
#  'sahuaripa',
#  'marsabit',
#  'nalut',
#  'bambous virieux',
#  'benghazi',
#  'verkhnyaya inta',
#  'sambava',
#  'malakal',
#  'coquimbo',
#  'bonnyville',
#  'pringsewu',
#  'lemesos',
#  'egvekinot',
#  'semey',
#  'caldas novas',
#  'northam',
#  'baykit',
#  'saquarema',
#  'langxiang',
#  'pozo colorado',
#  'solhan',
#  'mergui',
#  'teya',
#  'portland',
#  'eyl',
#  'siyabuswa',
#  'high level',
#  'dzaoudzi',
#  'svetlyy',
#  'henties bay',
#  'odaile',
#  'qafsah',
#  'bhaderwah',
#  'sorong',
#  'goure',
#  'plettenberg bay',
#  'luau',
#  'sibolga',
#  'mulege',
#  'sept-iles',
#  'tottori',
#  'guider',
#  'fort wellington',
#  'bloomfield',
#  'ozgon',
#  'mahina',
#  'ostersund',
#  'sandata',
#  'fram',
#  'itarema',
#  'pisco',
#  'calawag',
#  'dong hoi',
#  'umzimvubu',
#  'coahuayana',
#  'inhambane',
#  'arenal',
#  'port-gentil',
#  'muli',
#  'bosaso',
#  'bathsheba',
#  'los llanos de aridane',
#  'verkhnetulomskiy',
#  'innisfail',
#  'erzincan',
#  'lufkin',
#  'tarudant',
#  'corn island',
#  'matara',
#  'nizhneyansk',
#  'kushmurun',
#  'nyaunglebin',
#  'skagastrond',
#  'nhulunbuy',
#  'glasgow',
#  'iquitos',
#  'prince rupert',
#  'macon',
#  'granada',
#  'kamaishi',
#  'saleaula',
#  'lethem',
#  'margate',
#  'ordynskoye',
#  'dongsheng',
#  'guozhen',
#  'marrakesh',
#  'lexington park',
#  'yaan',
#  'tuggurt',
#  'senador jose porfirio',
#  'zarasai',
#  'tanta',
#  'pontarlier',
#  'lichinga',
#  'hailey',
#  'coihueco',
#  'beloha',
#  'paka',
#  'vytegra',
#  'rohnert park',
#  'nizhniy kuranakh',
#  'shakiso',
#  'kiruna',
#  'ampanihy',
#  'hauterive',
#  'marathon',
#  'grindavik',
#  'emerald',
#  'adrar',
#  'staryy nadym',
#  'saint-alexandre',
#  'hondo',
#  'namwala',
#  'narrabri',
#  'chicama',
#  'mount gambier',
#  'srivardhan',
#  'morrope',
#  'taylorville',
#  'kidal',
#  'sakaiminato',
#  'tessalit',
#  'kyzyl-suu',
#  'nenjiang',
#  'bad wildbad',
#  'namibe',
#  'tyukalinsk',
#  'san carlos de bariloche',
#  'dire',
#  'ulladulla',
#  'barinas',
#  'tabou',
#  'nogent-sur-oise',
#  'tortoli',
#  'chamba',
#  'guerrero negro',
#  'highlands ranch',
#  'barra patuca',
#  'jieshi',
#  'fornosovo',
#  'kindu',
#  'janakpur',
#  'bilibino',
#  'tual',
#  'jacareacanga',
#  'kungurtug',
#  'mayumba',
#  'huaidian',
#  'portree',
#  'marcona',
#  'tulun',
#  'ulkan',
#  'karkaralinsk',
#  'cockburn town',
#  'tazovskiy',
#  'karpogory',
#  'wajima',
#  'enshi',
#  'vierzon',
#  'kamenskoye',
#  'wiener neustadt',
#  'mercedes',
#  'kintinku',
#  'banda aceh',
#  'pacifica',
#  'karlshamn',
#  'vaureal',
#  'prejmer',
#  'la brea',
#  'beira',
#  'caloundra',
#  'sao joao do paraiso',
#  'nazca',
#  'pinhao',
#  'husavik',
#  'ust-nera',
#  'berbera',
#  'eydhafushi',
#  'mabaruma',
#  'murray bridge',
#  'pochutla',
#  'nuuk',
#  'kawalu',
#  'waingapu',
#  'wulanhaote',
#  'ostrovnoy',
#  'puno',
#  'yaring',
#  'jamame',
#  'otofuke',
#  'fort saint john',
#  'pitimbu',
#  'flin flon',
#  'havre-saint-pierre',
#  'cap malheureux',
#  'alanya',
#  'lynn haven',
#  'ous',
#  'san policarpo',
#  'barcelos',
#  'malwan',
#  'maroua',
#  'gizo',
#  'tambul',
#  'kyren',
#  'batagay',
#  'necochea',
#  'cornelio procopio',
#  'oksfjord',
#  'lumphat',
#  'lyndon',
#  'sillod',
#  'mokobeng',
#  'aitape',
#  'raudeberg',
#  'osakarovka',
#  'oranjemund',
#  'pekan',
#  'urumqi',
#  'salalah',
#  'planaltina',
#  'myingyan',
#  'monsenhor gil',
#  'katesh',
#  'kunming',
#  'falealupo',
#  'port shepstone',
#  'kudahuvadhoo',
#  'cantanhede',
#  'wana',
#  'nivala',
#  'acapulco',
#  'sisimiut',
#  'chandbali',
#  'lagos',
#  'nisia floresta',
#  'pouebo',
#  'bubaque',
#  'puerto madryn',
#  'porbandar',
#  'dwarka',
#  'opuwo',
#  'zhoucheng',
#  'lavumisa',
#  'daru',
#  'vila',
#  'vega de alatorre',
#  'zdunska wola',
#  'takab',
#  'karratha',
#  'wajir',
#  'kautokeino',
#  'yuanping',
#  'yeovil',
#  'komsomolets',
#  'codajas',
#  'vila do maio',
#  'dicabisagan',
#  'sovetskiy',
#  'horsham',
#  'oltu',
#  'edd',
#  'micomeseng',
#  'wharton',
#  'shache',
#  'grand gaube',
#  'mtimbira',
#  'antofagasta',
#  'sorrento',
#  'catumbela',
#  'kita',
#  'broome',
#  'guasdualito',
#  'halifax',
#  'balabac',
#  'nicoya',
#  'erenhot',
#  'vasilsursk',
#  'gimli',
#  'tuburan',
#  'khandyga',
#  'schwerin',
#  'iquique',
#  'luancheng',
#  'maxixe',
#  'palabuhanratu',
#  'victor harbor',
#  'atyrau',
#  'lasa']

# %%
url='http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID='+weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(30)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current_weather=city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          'Current Description':city_current_weather})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | ribeira grande
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | arlit
# Processing Record 6 of Set 1 | boguchany
# Processing Record 7 of Set 1 | arrifes
# Processing Record 8 of Set 1 | myanaung
# Processing Record 9 of Set 1 | champasak
# Processing Record 10 of Set 1 | ponta do sol
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | bilma
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | zonguldak
# Processing Record 18 of Set 1 | kisangani
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | maunabo
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | caravelas
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | onega
# Processing Record 26 of Set 1 | saint george
# Processing Record 27 of Set 1 | betong
# Processing Record 28 of Set 1 | bayamo
# Processing Record 29 of Set 1 | olafsvik
# Processing Record 30 of Set 1 | prainha
# Processing Record 31 of Set 1 | vila velha
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | peniche
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | carupano
# Processing Record 36 of Set 1 | codrington
# Processing Record 37 of Set 1 | vestmannaeyjar
# Processing Record 38 of Set 1 | xushan
# Processing Record 39 of Set 1 | pevek
# Processing Record 40 of Set 1 | nishihara
# Processing Record 41 of Set 1 | norman wells
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | pasighat
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | bacolod
# Processing Record 47 of Set 1 | jinchang
# Processing Record 48 of Set 1 | cochrane
# Processing Record 49 of Set 1 | kalmunai
# Processing Record 50 of Set 1 | te anau
# Processing Record 1 of Set 2 | kavaratti
# Processing Record 2 of Set 2 | maarianhamina
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | laguna
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | nalbari
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 2 | burnie
# Processing Record 10 of Set 2 | ongandjera
# Processing Record 11 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 2 | dubai
# Processing Record 13 of Set 2 | banff
# Processing Record 14 of Set 2 | harper
# Processing Record 15 of Set 2 | arraial do cabo
# Processing Record 16 of Set 2 | lebu
# Processing Record 17 of Set 2 | faya
# Processing Record 18 of Set 2 | fortuna
# Processing Record 19 of Set 2 | kanigiri
# Processing Record 20 of Set 2 | lagoa
# Processing Record 21 of Set 2 | orlik
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | severo-kurilsk
# Processing Record 24 of Set 2 | sao miguel
# Processing Record 25 of Set 2 | san cristobal
# Processing Record 26 of Set 2 | kaitangata
# Processing Record 27 of Set 2 | srednekolymsk
# Processing Record 28 of Set 2 | hambantota
# Processing Record 29 of Set 2 | araouane
# Processing Record 30 of Set 2 | terney
# Processing Record 31 of Set 2 | jumla
# Processing Record 32 of Set 2 | goderich
# Processing Record 33 of Set 2 | beringovskiy
# Processing Record 34 of Set 2 | bismarck
# Processing Record 35 of Set 2 | linxi
# Processing Record 36 of Set 2 | republic
# Processing Record 37 of Set 2 | pemangkat
# Processing Record 38 of Set 2 | fukue
# Processing Record 39 of Set 2 | svetlogorsk
# Processing Record 40 of Set 2 | neiafu
# Processing Record 41 of Set 2 | saskylakh
# Processing Record 42 of Set 2 | sechura
# Processing Record 43 of Set 2 | nanlong
# Processing Record 44 of Set 2 | dikson
# Processing Record 45 of Set 2 | calbuco
# Processing Record 46 of Set 2 | nagorsk
# Processing Record 47 of Set 2 | coruripe
# Processing Record 48 of Set 2 | tiksi
# Processing Record 49 of Set 2 | longyearbyen
# Processing Record 50 of Set 2 | qurbah
# City not found. Skipping...
# Processing Record 1 of Set 3 | nikolskoye
# Processing Record 2 of Set 3 | salinas
# Processing Record 3 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 3 | la ronge
# Processing Record 5 of Set 3 | flinders
# Processing Record 6 of Set 3 | senanga
# Processing Record 7 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | ravar
# Processing Record 10 of Set 3 | rajula
# Processing Record 11 of Set 3 | megion
# Processing Record 12 of Set 3 | port keats
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | olot
# Processing Record 16 of Set 3 | zeljezno polje
# Processing Record 17 of Set 3 | mataura
# Processing Record 18 of Set 3 | clyde river
# Processing Record 19 of Set 3 | mansa
# Processing Record 20 of Set 3 | khani
# Processing Record 21 of Set 3 | yamada
# Processing Record 22 of Set 3 | concepcion del oro
# Processing Record 23 of Set 3 | linhares
# Processing Record 24 of Set 3 | luderitz
# Processing Record 25 of Set 3 | byron bay
# Processing Record 26 of Set 3 | aswan
# Processing Record 27 of Set 3 | lata
# Processing Record 28 of Set 3 | bandarbeyla
# Processing Record 29 of Set 3 | esperance
# Processing Record 30 of Set 3 | port moresby
# Processing Record 31 of Set 3 | palmer
# Processing Record 32 of Set 3 | cherskiy
# Processing Record 33 of Set 3 | mouzakion
# City not found. Skipping...
# Processing Record 34 of Set 3 | upernavik
# Processing Record 35 of Set 3 | faanui
# Processing Record 36 of Set 3 | smithers
# Processing Record 37 of Set 3 | tomiya
# Processing Record 38 of Set 3 | busselton
# Processing Record 39 of Set 3 | port alfred
# Processing Record 40 of Set 3 | kahului
# Processing Record 41 of Set 3 | hilo
# Processing Record 42 of Set 3 | kodiak
# Processing Record 43 of Set 3 | lompoc
# Processing Record 44 of Set 3 | bethel
# Processing Record 45 of Set 3 | richard toll
# City not found. Skipping...
# Processing Record 46 of Set 3 | thompson
# Processing Record 47 of Set 3 | koulamoutou
# Processing Record 48 of Set 3 | nago
# Processing Record 49 of Set 3 | zhigansk
# Processing Record 50 of Set 3 | matale
# Processing Record 1 of Set 4 | ambon
# Processing Record 2 of Set 4 | hit
# Processing Record 3 of Set 4 | kirakira
# Processing Record 4 of Set 4 | borogontsy
# Processing Record 5 of Set 4 | ileza
# Processing Record 6 of Set 4 | korla
# Processing Record 7 of Set 4 | bonavista
# Processing Record 8 of Set 4 | port elizabeth
# Processing Record 9 of Set 4 | yershov
# Processing Record 10 of Set 4 | knysna
# Processing Record 11 of Set 4 | kilindoni
# Processing Record 12 of Set 4 | rocha
# Processing Record 13 of Set 4 | ausa
# Processing Record 14 of Set 4 | coihaique
# Processing Record 15 of Set 4 | hamilton
# Processing Record 16 of Set 4 | marzuq
# Processing Record 17 of Set 4 | xique-xique
# Processing Record 18 of Set 4 | qaanaaq
# Processing Record 19 of Set 4 | padang
# Processing Record 20 of Set 4 | cidreira
# Processing Record 21 of Set 4 | airai
# Processing Record 22 of Set 4 | port lincoln
# Processing Record 23 of Set 4 | shenjiamen
# Processing Record 24 of Set 4 | vardo
# Processing Record 25 of Set 4 | meulaboh
# Processing Record 26 of Set 4 | talavera de la reina
# Processing Record 27 of Set 4 | mahebourg
# Processing Record 28 of Set 4 | mirnyy
# Processing Record 29 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 4 | chapais
# Processing Record 31 of Set 4 | namatanai
# Processing Record 32 of Set 4 | katsuura
# Processing Record 33 of Set 4 | balboa
# Processing Record 34 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 4 | mar del plata
# Processing Record 36 of Set 4 | avarua
# Processing Record 37 of Set 4 | evanston
# Processing Record 38 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 4 | nantucket
# Processing Record 40 of Set 4 | viedma
# Processing Record 41 of Set 4 | hami
# Processing Record 42 of Set 4 | russkaya polyana
# Processing Record 43 of Set 4 | nanortalik
# Processing Record 44 of Set 4 | cayenne
# Processing Record 45 of Set 4 | ito
# Processing Record 46 of Set 4 | maldonado
# Processing Record 47 of Set 4 | hovd
# Processing Record 48 of Set 4 | villa union
# Processing Record 49 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 4 | lumut
# Processing Record 1 of Set 5 | mandal
# Processing Record 2 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 5 | victoria
# Processing Record 4 of Set 5 | mishkino
# Processing Record 5 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 6 of Set 5 | san patricio
# Processing Record 7 of Set 5 | vaini
# Processing Record 8 of Set 5 | saint-francois
# Processing Record 9 of Set 5 | narsaq
# Processing Record 10 of Set 5 | batagay-alyta
# Processing Record 11 of Set 5 | roald
# Processing Record 12 of Set 5 | georgetown
# Processing Record 13 of Set 5 | leningradskiy
# Processing Record 14 of Set 5 | meiringen
# Processing Record 15 of Set 5 | shakawe
# Processing Record 16 of Set 5 | fougamou
# Processing Record 17 of Set 5 | vilyuysk
# Processing Record 18 of Set 5 | brikama
# Processing Record 19 of Set 5 | sao felix do xingu
# Processing Record 20 of Set 5 | saldanha
# Processing Record 21 of Set 5 | maltahohe
# Processing Record 22 of Set 5 | saint anthony
# Processing Record 23 of Set 5 | maamba
# Processing Record 24 of Set 5 | nemuro
# Processing Record 25 of Set 5 | castellarano
# Processing Record 26 of Set 5 | luanda
# Processing Record 27 of Set 5 | sao filipe
# Processing Record 28 of Set 5 | arkhipo-osipovka
# Processing Record 29 of Set 5 | phan thiet
# Processing Record 30 of Set 5 | castro
# Processing Record 31 of Set 5 | vanimo
# Processing Record 32 of Set 5 | college
# Processing Record 33 of Set 5 | karpathos
# Processing Record 34 of Set 5 | bar harbor
# Processing Record 35 of Set 5 | deputatskiy
# Processing Record 36 of Set 5 | kanlagay
# Processing Record 37 of Set 5 | saint-philippe
# Processing Record 38 of Set 5 | gisborne
# Processing Record 39 of Set 5 | pemberton
# Processing Record 40 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 5 | richards bay
# Processing Record 42 of Set 5 | tura
# Processing Record 43 of Set 5 | lorengau
# Processing Record 44 of Set 5 | mackay
# Processing Record 45 of Set 5 | inirida
# Processing Record 46 of Set 5 | caraguatatuba
# Processing Record 47 of Set 5 | san rafael del sur
# Processing Record 48 of Set 5 | southbridge
# Processing Record 49 of Set 5 | svetlaya
# Processing Record 50 of Set 5 | ilulissat
# Processing Record 1 of Set 6 | aklavik
# Processing Record 2 of Set 6 | atuona
# Processing Record 3 of Set 6 | hokitika
# Processing Record 4 of Set 6 | leh
# Processing Record 5 of Set 6 | ridgeland
# Processing Record 6 of Set 6 | yonago
# Processing Record 7 of Set 6 | sondershausen
# Processing Record 8 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 6 | saint-pierre
# Processing Record 10 of Set 6 | shimoda
# Processing Record 11 of Set 6 | bara
# Processing Record 12 of Set 6 | ormara
# Processing Record 13 of Set 6 | buala
# Processing Record 14 of Set 6 | ahuimanu
# Processing Record 15 of Set 6 | atherton
# Processing Record 16 of Set 6 | santiago de cao
# Processing Record 17 of Set 6 | serebryansk
# Processing Record 18 of Set 6 | vadso
# Processing Record 19 of Set 6 | porto novo
# Processing Record 20 of Set 6 | whitehorse
# Processing Record 21 of Set 6 | klaksvik
# Processing Record 22 of Set 6 | provideniya
# Processing Record 23 of Set 6 | tuatapere
# Processing Record 24 of Set 6 | condega
# Processing Record 25 of Set 6 | pionerskiy
# Processing Record 26 of Set 6 | basna
# Processing Record 27 of Set 6 | oak harbor
# Processing Record 28 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 6 | takoradi
# Processing Record 30 of Set 6 | barranca
# Processing Record 31 of Set 6 | natal
# Processing Record 32 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 6 | high rock
# Processing Record 34 of Set 6 | guia de isora
# Processing Record 35 of Set 6 | cururupu
# Processing Record 36 of Set 6 | mount isa
# Processing Record 37 of Set 6 | haines junction
# Processing Record 38 of Set 6 | ahipara
# Processing Record 39 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 6 | vao
# Processing Record 41 of Set 6 | naze
# Processing Record 42 of Set 6 | matay
# Processing Record 43 of Set 6 | anadyr
# Processing Record 44 of Set 6 | ranong
# Processing Record 45 of Set 6 | harboore
# Processing Record 46 of Set 6 | osmanabad
# Processing Record 47 of Set 6 | ancud
# Processing Record 48 of Set 6 | dumai
# Processing Record 49 of Set 6 | torbay
# Processing Record 50 of Set 6 | kenda
# Processing Record 1 of Set 7 | bengkalis
# City not found. Skipping...
# Processing Record 2 of Set 7 | mgandu
# Processing Record 3 of Set 7 | manokwari
# Processing Record 4 of Set 7 | thilogne
# City not found. Skipping...
# Processing Record 5 of Set 7 | ippy
# Processing Record 6 of Set 7 | isangel
# Processing Record 7 of Set 7 | hofn
# Processing Record 8 of Set 7 | porosozero
# Processing Record 9 of Set 7 | duluth
# Processing Record 10 of Set 7 | chumikan
# Processing Record 11 of Set 7 | bengkulu
# Processing Record 12 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 7 | nome
# Processing Record 14 of Set 7 | hamamatsu
# Processing Record 15 of Set 7 | imbituba
# Processing Record 16 of Set 7 | tuktoyaktuk
# Processing Record 17 of Set 7 | san julian
# Processing Record 18 of Set 7 | dingle
# Processing Record 19 of Set 7 | japura
# Processing Record 20 of Set 7 | safwah
# City not found. Skipping...
# Processing Record 21 of Set 7 | sao joao da barra
# Processing Record 22 of Set 7 | quatre cocos
# Processing Record 23 of Set 7 | valparaiso
# Processing Record 24 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 7 | hakkari
# Processing Record 26 of Set 7 | kodinar
# Processing Record 27 of Set 7 | zeya
# Processing Record 28 of Set 7 | carnarvon
# Processing Record 29 of Set 7 | tagusao
# Processing Record 30 of Set 7 | alofi
# Processing Record 31 of Set 7 | honningsvag
# Processing Record 32 of Set 7 | lloydminster
# Processing Record 33 of Set 7 | odweyne
# Processing Record 34 of Set 7 | guye
# Processing Record 35 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 7 | gouyave
# Processing Record 37 of Set 7 | bontang
# Processing Record 38 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 7 | scarborough
# Processing Record 40 of Set 7 | carutapera
# Processing Record 41 of Set 7 | sitka
# Processing Record 42 of Set 7 | santa ines
# Processing Record 43 of Set 7 | solnechnyy
# Processing Record 44 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 7 | emba
# Processing Record 46 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 7 | mildura
# Processing Record 48 of Set 7 | lilongwe
# Processing Record 49 of Set 7 | wenatchee
# Processing Record 50 of Set 7 | aykhal
# Processing Record 1 of Set 8 | jiazi
# Processing Record 2 of Set 8 | le mars
# Processing Record 3 of Set 8 | zmievka
# City not found. Skipping...
# Processing Record 4 of Set 8 | gushikawa
# Processing Record 5 of Set 8 | cozumel
# Processing Record 6 of Set 8 | gravdal
# Processing Record 7 of Set 8 | exaplatanos
# Processing Record 8 of Set 8 | xining
# Processing Record 9 of Set 8 | manyoni
# Processing Record 10 of Set 8 | ust-kuyga
# Processing Record 11 of Set 8 | sola
# Processing Record 12 of Set 8 | antalaha
# Processing Record 13 of Set 8 | sault sainte marie
# Processing Record 14 of Set 8 | ihosy
# Processing Record 15 of Set 8 | kosmynino
# Processing Record 16 of Set 8 | ossora
# Processing Record 17 of Set 8 | melo
# Processing Record 18 of Set 8 | broken hill
# Processing Record 19 of Set 8 | cap-chat
# Processing Record 20 of Set 8 | san vicente
# Processing Record 21 of Set 8 | tabuk
# Processing Record 22 of Set 8 | souillac
# Processing Record 23 of Set 8 | taoudenni
# Processing Record 24 of Set 8 | santa cruz de tenerife
# Processing Record 25 of Set 8 | hualmay
# Processing Record 26 of Set 8 | hobyo
# Processing Record 27 of Set 8 | north bend
# Processing Record 28 of Set 8 | geraldton
# Processing Record 29 of Set 8 | kinna
# Processing Record 30 of Set 8 | golden
# Processing Record 31 of Set 8 | jiangyou
# Processing Record 32 of Set 8 | komsomolskiy
# Processing Record 33 of Set 8 | danville
# Processing Record 34 of Set 8 | freeport
# Processing Record 35 of Set 8 | gamba
# Processing Record 36 of Set 8 | havelock
# Processing Record 37 of Set 8 | walvis bay
# Processing Record 38 of Set 8 | asosa
# Processing Record 39 of Set 8 | rapid valley
# Processing Record 40 of Set 8 | kruisfontein
# Processing Record 41 of Set 8 | auburn
# Processing Record 42 of Set 8 | pimentel
# Processing Record 43 of Set 8 | roma
# Processing Record 44 of Set 8 | pangody
# Processing Record 45 of Set 8 | pacific grove
# Processing Record 46 of Set 8 | zarubino
# Processing Record 47 of Set 8 | westport
# Processing Record 48 of Set 8 | picota
# Processing Record 49 of Set 8 | rocky mountain house
# Processing Record 50 of Set 8 | khatanga
# Processing Record 1 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 2 of Set 9 | columbus
# Processing Record 3 of Set 9 | camopi
# Processing Record 4 of Set 9 | kaeo
# Processing Record 5 of Set 9 | lithakia
# Processing Record 6 of Set 9 | koungou
# Processing Record 7 of Set 9 | elko
# Processing Record 8 of Set 9 | gormi
# City not found. Skipping...
# Processing Record 9 of Set 9 | avera
# Processing Record 10 of Set 9 | verkhnevilyuysk
# Processing Record 11 of Set 9 | vagay
# Processing Record 12 of Set 9 | kambove
# Processing Record 13 of Set 9 | fairbanks
# Processing Record 14 of Set 9 | mariana
# Processing Record 15 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 16 of Set 9 | lewisporte
# Processing Record 17 of Set 9 | xichang
# Processing Record 18 of Set 9 | dzhebariki-khaya
# Processing Record 19 of Set 9 | makakilo city
# Processing Record 20 of Set 9 | juegang
# Processing Record 21 of Set 9 | stephenville
# Processing Record 22 of Set 9 | arman
# Processing Record 23 of Set 9 | tezu
# Processing Record 24 of Set 9 | san pedro
# Processing Record 25 of Set 9 | abong mbang
# Processing Record 26 of Set 9 | mont-de-marsan
# Processing Record 27 of Set 9 | pangnirtung
# Processing Record 28 of Set 9 | port hardy
# Processing Record 29 of Set 9 | aripuana
# Processing Record 30 of Set 9 | usta muhammad
# Processing Record 31 of Set 9 | pilar
# Processing Record 32 of Set 9 | bassano
# Processing Record 33 of Set 9 | nakapiripirit
# Processing Record 34 of Set 9 | labuhan
# Processing Record 35 of Set 9 | vila franca do campo
# Processing Record 36 of Set 9 | birjand
# Processing Record 37 of Set 9 | williamsport
# Processing Record 38 of Set 9 | muros
# Processing Record 39 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 9 | shamgarh
# Processing Record 41 of Set 9 | yelnya
# Processing Record 42 of Set 9 | atar
# Processing Record 43 of Set 9 | conceicao do araguaia
# Processing Record 44 of Set 9 | comodoro rivadavia
# Processing Record 45 of Set 9 | gelemso
# Processing Record 46 of Set 9 | katobu
# Processing Record 47 of Set 9 | ledyard
# Processing Record 48 of Set 9 | galveston
# Processing Record 49 of Set 9 | zalari
# Processing Record 50 of Set 9 | mikhaylovka
# Processing Record 1 of Set 10 | janauba
# Processing Record 2 of Set 10 | pamyat parizhskoy kommuny
# Processing Record 3 of Set 10 | uvalde
# Processing Record 4 of Set 10 | kavieng
# Processing Record 5 of Set 10 | rongcheng
# Processing Record 6 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 7 of Set 10 | berlevag
# Processing Record 8 of Set 10 | maine-soroa
# Processing Record 9 of Set 10 | nyurba
# Processing Record 10 of Set 10 | bahia blanca
# Processing Record 11 of Set 10 | lavrentiya
# Processing Record 12 of Set 10 | maragogi
# Processing Record 13 of Set 10 | tiznit
# Processing Record 14 of Set 10 | mont-dore
# Processing Record 15 of Set 10 | kenai
# Processing Record 16 of Set 10 | gerash
# Processing Record 17 of Set 10 | beeville
# Processing Record 18 of Set 10 | hasaki
# Processing Record 19 of Set 10 | kopyevo
# City not found. Skipping...
# Processing Record 20 of Set 10 | iqaluit
# Processing Record 21 of Set 10 | chumphon
# Processing Record 22 of Set 10 | jingdezhen
# Processing Record 23 of Set 10 | verkh-usugli
# Processing Record 24 of Set 10 | pelym
# Processing Record 25 of Set 10 | winslow
# Processing Record 26 of Set 10 | vostok
# Processing Record 27 of Set 10 | paamiut
# Processing Record 28 of Set 10 | vestmanna
# Processing Record 29 of Set 10 | gari
# Processing Record 30 of Set 10 | umm lajj
# Processing Record 31 of Set 10 | boshnyakovo
# Processing Record 32 of Set 10 | yerbogachen
# Processing Record 33 of Set 10 | dmitriyev-lgovskiy
# City not found. Skipping...
# Processing Record 34 of Set 10 | jacala
# Processing Record 35 of Set 10 | boende
# Processing Record 36 of Set 10 | sahuaripa
# Processing Record 37 of Set 10 | marsabit
# Processing Record 38 of Set 10 | nalut
# Processing Record 39 of Set 10 | bambous virieux
# Processing Record 40 of Set 10 | benghazi
# Processing Record 41 of Set 10 | verkhnyaya inta
# Processing Record 42 of Set 10 | sambava
# Processing Record 43 of Set 10 | malakal
# Processing Record 44 of Set 10 | coquimbo
# Processing Record 45 of Set 10 | bonnyville
# Processing Record 46 of Set 10 | pringsewu
# Processing Record 47 of Set 10 | lemesos
# City not found. Skipping...
# Processing Record 48 of Set 10 | egvekinot
# Processing Record 49 of Set 10 | semey
# Processing Record 50 of Set 10 | caldas novas
# Processing Record 1 of Set 11 | northam
# Processing Record 2 of Set 11 | baykit
# Processing Record 3 of Set 11 | saquarema
# Processing Record 4 of Set 11 | langxiang
# Processing Record 5 of Set 11 | pozo colorado
# Processing Record 6 of Set 11 | solhan
# Processing Record 7 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 8 of Set 11 | teya
# Processing Record 9 of Set 11 | portland
# Processing Record 10 of Set 11 | eyl
# Processing Record 11 of Set 11 | siyabuswa
# Processing Record 12 of Set 11 | high level
# Processing Record 13 of Set 11 | dzaoudzi
# Processing Record 14 of Set 11 | svetlyy
# Processing Record 15 of Set 11 | henties bay
# Processing Record 16 of Set 11 | odaile
# Processing Record 17 of Set 11 | qafsah
# City not found. Skipping...
# Processing Record 18 of Set 11 | bhaderwah
# Processing Record 19 of Set 11 | sorong
# Processing Record 20 of Set 11 | goure
# Processing Record 21 of Set 11 | plettenberg bay
# Processing Record 22 of Set 11 | luau
# Processing Record 23 of Set 11 | sibolga
# Processing Record 24 of Set 11 | mulege
# Processing Record 25 of Set 11 | sept-iles
# Processing Record 26 of Set 11 | tottori
# Processing Record 27 of Set 11 | guider
# Processing Record 28 of Set 11 | fort wellington
# Processing Record 29 of Set 11 | bloomfield
# Processing Record 30 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 31 of Set 11 | mahina
# Processing Record 32 of Set 11 | ostersund
# Processing Record 33 of Set 11 | sandata
# Processing Record 34 of Set 11 | fram
# Processing Record 35 of Set 11 | itarema
# Processing Record 36 of Set 11 | pisco
# Processing Record 37 of Set 11 | calawag
# Processing Record 38 of Set 11 | dong hoi
# Processing Record 39 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 11 | coahuayana
# Processing Record 41 of Set 11 | inhambane
# Processing Record 42 of Set 11 | arenal
# Processing Record 43 of Set 11 | port-gentil
# Processing Record 44 of Set 11 | muli
# Processing Record 45 of Set 11 | bosaso
# Processing Record 46 of Set 11 | bathsheba
# Processing Record 47 of Set 11 | los llanos de aridane
# Processing Record 48 of Set 11 | verkhnetulomskiy
# Processing Record 49 of Set 11 | innisfail
# Processing Record 50 of Set 11 | erzincan
# Processing Record 1 of Set 12 | lufkin
# Processing Record 2 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 3 of Set 12 | corn island
# Processing Record 4 of Set 12 | matara
# Processing Record 5 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 12 | kushmurun
# Processing Record 7 of Set 12 | nyaunglebin
# Processing Record 8 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 9 of Set 12 | nhulunbuy
# Processing Record 10 of Set 12 | glasgow
# Processing Record 11 of Set 12 | iquitos
# Processing Record 12 of Set 12 | prince rupert
# Processing Record 13 of Set 12 | macon
# Processing Record 14 of Set 12 | granada
# Processing Record 15 of Set 12 | kamaishi
# Processing Record 16 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 12 | lethem
# Processing Record 18 of Set 12 | margate
# Processing Record 19 of Set 12 | ordynskoye
# Processing Record 20 of Set 12 | dongsheng
# Processing Record 21 of Set 12 | guozhen
# Processing Record 22 of Set 12 | marrakesh
# Processing Record 23 of Set 12 | lexington park
# Processing Record 24 of Set 12 | yaan
# Processing Record 25 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 26 of Set 12 | senador jose porfirio
# Processing Record 27 of Set 12 | zarasai
# Processing Record 28 of Set 12 | tanta
# Processing Record 29 of Set 12 | pontarlier
# Processing Record 30 of Set 12 | lichinga
# Processing Record 31 of Set 12 | hailey
# Processing Record 32 of Set 12 | coihueco
# Processing Record 33 of Set 12 | beloha
# Processing Record 34 of Set 12 | paka
# Processing Record 35 of Set 12 | vytegra
# Processing Record 36 of Set 12 | rohnert park
# Processing Record 37 of Set 12 | nizhniy kuranakh
# Processing Record 38 of Set 12 | shakiso
# Processing Record 39 of Set 12 | kiruna
# Processing Record 40 of Set 12 | ampanihy
# Processing Record 41 of Set 12 | hauterive
# Processing Record 42 of Set 12 | marathon
# Processing Record 43 of Set 12 | grindavik
# Processing Record 44 of Set 12 | emerald
# Processing Record 45 of Set 12 | adrar
# Processing Record 46 of Set 12 | staryy nadym
# Processing Record 47 of Set 12 | saint-alexandre
# Processing Record 48 of Set 12 | hondo
# Processing Record 49 of Set 12 | namwala
# Processing Record 50 of Set 12 | narrabri
# Processing Record 1 of Set 13 | chicama
# Processing Record 2 of Set 13 | mount gambier
# Processing Record 3 of Set 13 | srivardhan
# Processing Record 4 of Set 13 | morrope
# Processing Record 5 of Set 13 | taylorville
# Processing Record 6 of Set 13 | kidal
# Processing Record 7 of Set 13 | sakaiminato
# Processing Record 8 of Set 13 | tessalit
# Processing Record 9 of Set 13 | kyzyl-suu
# Processing Record 10 of Set 13 | nenjiang
# Processing Record 11 of Set 13 | bad wildbad
# Processing Record 12 of Set 13 | namibe
# Processing Record 13 of Set 13 | tyukalinsk
# Processing Record 14 of Set 13 | san carlos de bariloche
# Processing Record 15 of Set 13 | dire
# Processing Record 16 of Set 13 | ulladulla
# Processing Record 17 of Set 13 | barinas
# Processing Record 18 of Set 13 | tabou
# Processing Record 19 of Set 13 | nogent-sur-oise
# Processing Record 20 of Set 13 | tortoli
# Processing Record 21 of Set 13 | chamba
# Processing Record 22 of Set 13 | guerrero negro
# Processing Record 23 of Set 13 | highlands ranch
# Processing Record 24 of Set 13 | barra patuca
# Processing Record 25 of Set 13 | jieshi
# Processing Record 26 of Set 13 | fornosovo
# Processing Record 27 of Set 13 | kindu
# Processing Record 28 of Set 13 | janakpur
# Processing Record 29 of Set 13 | bilibino
# Processing Record 30 of Set 13 | tual
# Processing Record 31 of Set 13 | jacareacanga
# Processing Record 32 of Set 13 | kungurtug
# Processing Record 33 of Set 13 | mayumba
# Processing Record 34 of Set 13 | huaidian
# Processing Record 35 of Set 13 | portree
# Processing Record 36 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 13 | tulun
# Processing Record 38 of Set 13 | ulkan
# Processing Record 39 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 40 of Set 13 | cockburn town
# Processing Record 41 of Set 13 | tazovskiy
# Processing Record 42 of Set 13 | karpogory
# Processing Record 43 of Set 13 | wajima
# Processing Record 44 of Set 13 | enshi
# Processing Record 45 of Set 13 | vierzon
# Processing Record 46 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 13 | wiener neustadt
# Processing Record 48 of Set 13 | mercedes
# Processing Record 49 of Set 13 | kintinku
# Processing Record 50 of Set 13 | banda aceh
# Processing Record 1 of Set 14 | pacifica
# Processing Record 2 of Set 14 | karlshamn
# Processing Record 3 of Set 14 | vaureal
# Processing Record 4 of Set 14 | prejmer
# Processing Record 5 of Set 14 | la brea
# Processing Record 6 of Set 14 | beira
# Processing Record 7 of Set 14 | caloundra
# Processing Record 8 of Set 14 | sao joao do paraiso
# Processing Record 9 of Set 14 | nazca
# Processing Record 10 of Set 14 | pinhao
# Processing Record 11 of Set 14 | husavik
# Processing Record 12 of Set 14 | ust-nera
# Processing Record 13 of Set 14 | berbera
# Processing Record 14 of Set 14 | eydhafushi
# Processing Record 15 of Set 14 | mabaruma
# Processing Record 16 of Set 14 | murray bridge
# Processing Record 17 of Set 14 | pochutla
# Processing Record 18 of Set 14 | nuuk
# Processing Record 19 of Set 14 | kawalu
# Processing Record 20 of Set 14 | waingapu
# Processing Record 21 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 22 of Set 14 | ostrovnoy
# Processing Record 23 of Set 14 | puno
# Processing Record 24 of Set 14 | yaring
# Processing Record 25 of Set 14 | jamame
# Processing Record 26 of Set 14 | otofuke
# Processing Record 27 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 28 of Set 14 | pitimbu
# Processing Record 29 of Set 14 | flin flon
# Processing Record 30 of Set 14 | havre-saint-pierre
# Processing Record 31 of Set 14 | cap malheureux
# Processing Record 32 of Set 14 | alanya
# Processing Record 33 of Set 14 | lynn haven
# Processing Record 34 of Set 14 | ous
# Processing Record 35 of Set 14 | san policarpo
# Processing Record 36 of Set 14 | barcelos
# Processing Record 37 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 38 of Set 14 | maroua
# Processing Record 39 of Set 14 | gizo
# Processing Record 40 of Set 14 | tambul
# City not found. Skipping...
# Processing Record 41 of Set 14 | kyren
# Processing Record 42 of Set 14 | batagay
# Processing Record 43 of Set 14 | necochea
# Processing Record 44 of Set 14 | cornelio procopio
# Processing Record 45 of Set 14 | oksfjord
# Processing Record 46 of Set 14 | lumphat
# Processing Record 47 of Set 14 | lyndon
# Processing Record 48 of Set 14 | sillod
# Processing Record 49 of Set 14 | mokobeng
# Processing Record 50 of Set 14 | aitape
# Processing Record 1 of Set 15 | raudeberg
# Processing Record 2 of Set 15 | osakarovka
# Processing Record 3 of Set 15 | oranjemund
# Processing Record 4 of Set 15 | pekan
# Processing Record 5 of Set 15 | urumqi
# Processing Record 6 of Set 15 | salalah
# Processing Record 7 of Set 15 | planaltina
# Processing Record 8 of Set 15 | myingyan
# Processing Record 9 of Set 15 | monsenhor gil
# Processing Record 10 of Set 15 | katesh
# Processing Record 11 of Set 15 | kunming
# Processing Record 12 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 13 of Set 15 | port shepstone
# Processing Record 14 of Set 15 | kudahuvadhoo
# Processing Record 15 of Set 15 | cantanhede
# Processing Record 16 of Set 15 | wana
# Processing Record 17 of Set 15 | nivala
# Processing Record 18 of Set 15 | acapulco
# Processing Record 19 of Set 15 | sisimiut
# Processing Record 20 of Set 15 | chandbali
# Processing Record 21 of Set 15 | lagos
# Processing Record 22 of Set 15 | nisia floresta
# Processing Record 23 of Set 15 | pouebo
# Processing Record 24 of Set 15 | bubaque
# Processing Record 25 of Set 15 | puerto madryn
# Processing Record 26 of Set 15 | porbandar
# Processing Record 27 of Set 15 | dwarka
# Processing Record 28 of Set 15 | opuwo
# Processing Record 29 of Set 15 | zhoucheng
# Processing Record 30 of Set 15 | lavumisa
# Processing Record 31 of Set 15 | daru
# Processing Record 32 of Set 15 | vila
# Processing Record 33 of Set 15 | vega de alatorre
# Processing Record 34 of Set 15 | zdunska wola
# Processing Record 35 of Set 15 | takab
# Processing Record 36 of Set 15 | karratha
# Processing Record 37 of Set 15 | wajir
# Processing Record 38 of Set 15 | kautokeino
# Processing Record 39 of Set 15 | yuanping
# Processing Record 40 of Set 15 | yeovil
# Processing Record 41 of Set 15 | komsomolets
# Processing Record 42 of Set 15 | codajas
# Processing Record 43 of Set 15 | vila do maio
# Processing Record 44 of Set 15 | dicabisagan
# Processing Record 45 of Set 15 | sovetskiy
# Processing Record 46 of Set 15 | horsham
# Processing Record 47 of Set 15 | oltu
# Processing Record 48 of Set 15 | edd
# Processing Record 49 of Set 15 | micomeseng
# Processing Record 50 of Set 15 | wharton
# Processing Record 1 of Set 16 | shache
# Processing Record 2 of Set 16 | grand gaube
# Processing Record 3 of Set 16 | mtimbira
# Processing Record 4 of Set 16 | antofagasta
# Processing Record 5 of Set 16 | sorrento
# Processing Record 6 of Set 16 | catumbela
# Processing Record 7 of Set 16 | kita
# Processing Record 8 of Set 16 | broome
# Processing Record 9 of Set 16 | guasdualito
# Processing Record 10 of Set 16 | halifax
# Processing Record 11 of Set 16 | balabac
# Processing Record 12 of Set 16 | nicoya
# Processing Record 13 of Set 16 | erenhot
# Processing Record 14 of Set 16 | vasilsursk
# Processing Record 15 of Set 16 | gimli
# Processing Record 16 of Set 16 | tuburan
# Processing Record 17 of Set 16 | khandyga
# Processing Record 18 of Set 16 | schwerin
# Processing Record 19 of Set 16 | iquique
# Processing Record 20 of Set 16 | luancheng
# Processing Record 21 of Set 16 | maxixe
# Processing Record 22 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 16 | victor harbor
# Processing Record 24 of Set 16 | atyrau
# Processing Record 25 of Set 16 | lasa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Tally the number of cities in city_data
len(city_data)
# Out:
# 719

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas      CL -53.1500  -70.9167     35.71        69           0
# 1  Ribeira Grande      PT  38.5167  -28.7000     74.32        87          51
# 2         Ushuaia      AR -54.8000  -68.3000     33.46        86          75
# 3           Arlit      NE  18.7369    7.3853     93.47        27          91
# 4       Boguchany      RU  58.3814   97.4531     57.52        89          75
# 5         Arrifes      PT  37.7667  -25.7000     73.24        88          20
# 6        Myanaung      MM  18.2833   95.3167     75.94        91         100
# 7       Champasak      LA  14.7500  106.0000     71.74        99          88
# 8    Ponta Do Sol      PT  32.6667  -17.1000     75.43        69           3
# 9      Bredasdorp      ZA -34.5322   20.0403     50.45        71          36
#
#    Wind Speed Current Description
# 0        9.22           clear sky
# 1        5.79       broken clouds
# 2       14.97          light snow
# 3        6.20     overcast clouds
# 4        4.59       broken clouds
# 5        6.91          few clouds
# 6        3.91     overcast clouds
# 7        1.97     overcast clouds
# 8        2.66           clear sky
# 9        2.91    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file,index_label="City_ID")
